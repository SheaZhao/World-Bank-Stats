# %%
import numpy as np  # np becomes the namespace of numpy
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import requests
import matplotlib
matplotlib.style.use('ggplot')

# %matplotlib inline

# %%
 # !pip install ggplot
# trying this
from ggplot import *

import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# Set display options
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 10)

# %%
econ_data = pd.read_csv("/Users/Shea/Desktop/Python Project/Data_Extract_From_Jobs/Jobs_Data.csv")
econ_data
# Out:
#                   Country Name Country Code  \
# 0                  Afghanistan          AFG
# 1                  Afghanistan          AFG
# 2                  Afghanistan          AFG
# 3                  Afghanistan          AFG
# 4                  Afghanistan          AFG
# ...                        ...          ...
# 9234                       NaN          NaN
# 9235                       NaN          NaN
# 9236                       NaN          NaN
# 9237  Data from database: Jobs          NaN
# 9238  Last Updated: 10/15/2015          NaN
#
#                                             Series Name           Series Code  \
# 0     Age dependency ratio (% of working-age populat...           SP.POP.DPND
# 1     Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 2                                 GDP growth (annual %)     NY.GDP.MKTP.KD.ZG
# 3     GDP per capita, PPP (constant 2011 internation...     NY.GDP.PCAP.PP.KD
# ...

# %%
list(econ_data) # these are our column names
# Out:
# ['Country Name',
#  'Country Code',
#  'Series Name',
#  'Series Code',
#  '1990 [YR1990]',
#  '1991 [YR1991]',
#  '1992 [YR1992]',
#  '1993 [YR1993]',
#  '1994 [YR1994]',
#  '1995 [YR1995]',
#  '1996 [YR1996]',
#  '1997 [YR1997]',
#  '1998 [YR1998]',
#  '1999 [YR1999]',
#  '2000 [YR2000]',
#  '2001 [YR2001]',
#  '2002 [YR2002]',
#  '2003 [YR2003]',
#  '2004 [YR2004]',
#  '2005 [YR2005]',
#  '2006 [YR2006]',
#  '2007 [YR2007]',
#  '2008 [YR2008]',
#  '2009 [YR2009]',
#  '2010 [YR2010]',
#  '2011 [YR2011]',
#  '2012 [YR2012]',
#  '2013 [YR2013]',
#  '2014 [YR2014]',
#  'Most Recent Value [YR20111]']

# %%
econ_data['Series Name'] # there are 9238 levels in Series Name
# Out:
# 0       Age dependency ratio (% of working-age populat...
# 1       Foreign direct investment, net inflows (% of GDP)
# 2                                   GDP growth (annual %)
# 3       GDP per capita, PPP (constant 2011 internation...
# 4                      GDP per capita (constant 2005 US$)
#                               ...
# 9234                                                  NaN
# 9235                                                  NaN
# 9236                                                  NaN
# 9237                                                  NaN
# 9238                                                  NaN
# Name: Series Name, dtype: object

# %%
econ_data['Series Name'].unique() # these are the variables in the series column
# Out:
# array(['Age dependency ratio (% of working-age population)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'GDP growth (annual %)',
#        'GDP per capita, PPP (constant 2011 international $)',
#        'GDP per capita (constant 2005 US$)',
#        'GINI index (World Bank estimate)',
#        'Government expenditure on education, total (% of GDP)',
#        'Population ages 0-14 (% of total)',
#        'Population ages 15-64 (% of total)',
#        'Population ages 65 and above (% of total)',
#        'Population growth (annual %)', 'Population, total',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#        'Poverty headcount ratio at $3.10 a day (2011 PPP) (% of population)',
#        'Rural population (% of total population)',
#        'School enrollment, primary, female (% gross)',
#        'School enrollment, primary, male (% gross)',
#        'School enrollment, secondary (% gross)',
# ...

# %%
econ_data2 = econ_data.drop(['Series Code', 'Country Code'], axis=1) # remove Series Code & Country Code

# %%
econ_data2 = econ_data2.drop(econ_data2.columns.to_series()["1990 [YR1990]":"1999 [YR1999]"], axis=1) # also remove years before 2000

# %%
list(econ_data2)
# Out:
# ['Country Name',
#  'Series Name',
#  '2000 [YR2000]',
#  '2001 [YR2001]',
#  '2002 [YR2002]',
#  '2003 [YR2003]',
#  '2004 [YR2004]',
#  '2005 [YR2005]',
#  '2006 [YR2006]',
#  '2007 [YR2007]',
#  '2008 [YR2008]',
#  '2009 [YR2009]',
#  '2010 [YR2010]',
#  '2011 [YR2011]',
#  '2012 [YR2012]',
#  '2013 [YR2013]',
#  '2014 [YR2014]',
#  'Most Recent Value [YR20111]']

# %%
gdp_data = econ_data2 [econ_data2["Series Name"] == "GDP per capita (constant 2005 US$)"]
gdp_data
# Out:
#             Country Name                         Series Name  \
# 4            Afghanistan  GDP per capita (constant 2005 US$)
# 42               Albania  GDP per capita (constant 2005 US$)
# 80               Algeria  GDP per capita (constant 2005 US$)
# 118       American Samoa  GDP per capita (constant 2005 US$)
# 156              Andorra  GDP per capita (constant 2005 US$)
# ...                  ...                                 ...
# 9048  West Bank and Gaza  GDP per capita (constant 2005 US$)
# 9086               World  GDP per capita (constant 2005 US$)
# 9124         Yemen, Rep.  GDP per capita (constant 2005 US$)
# 9162              Zambia  GDP per capita (constant 2005 US$)
# 9200            Zimbabwe  GDP per capita (constant 2005 US$)
#
#          2000 [YR2000]     2001 [YR2001]     2002 [YR2002]     2003 [YR2003]  \
# 4                   ..                ..   239.69945131126   248.15663454984
# ...

# %%
gdp_dataMRY = gdp_data[['Country Name', 'Most Recent Value [YR20111]']] # just most recent year for each country
gdp_dataMRY
# Out:
#             Country Name Most Recent Value [YR20111]
# 4            Afghanistan            408.898697338172
# 42               Albania             3994.6254793373
# 80               Algeria            3400.73280198364
# 118       American Samoa                          ..
# 156              Andorra             34835.709370181
# ...                  ...                         ...
# 9048  West Bank and Gaza            1389.88143730736
# 9086               World            7995.81264521663
# 9124         Yemen, Rep.            709.469347534711
# 9162              Zambia            1032.80253199159
# 9200            Zimbabwe            455.102890388214
#
# [243 rows x 2 columns]

# %%
gdp_dataMRY.describe()
# Out:
#        Country Name Most Recent Value [YR20111]
# count           243                         243
# unique          243                         227
# top         Morocco                          ..
# freq              1                          17

# %%
gdp_MRY = ggplot(aes(x= 'Country Name', y= 'Most Recent Value [YR20111]'), data = gdp_dataMRY) + geom_bar(stat= 'identity', position= 'dodge') + coord_flip()

gdp_MRY
# Out:
# <ggplot: (310174314)>

# %%
gdp_dataTIME = gdp_data.drop(gdp_data.columns.to_series()["Most Recent Value [YR20111]"], axis=1)

# %%
gdp_dataT = gdp_dataTIME.drop(gdp_data.columns.to_series()["Series Name"], axis=1)

# %%
gdp_dataT
# Out:
#             Country Name     2000 [YR2000]     2001 [YR2001]  \
# 4            Afghanistan                ..                ..
# 42               Albania  2085.58272052769  2252.61474657217
# 80               Algeria  2530.01144247309  2612.63775413795
# 118       American Samoa                ..                ..
# 156              Andorra   33700.762128571  34494.7285343218
# ...                  ...               ...               ...
# 9048  West Bank and Gaza  1358.87355061492  1239.53825226878
# 9086               World  6672.63303446756  6706.46713090118
# 9124         Yemen, Rep.  766.138663048624  773.077542109061
# 9162              Zambia  582.624115719816  598.007941758577
# 9200            Zimbabwe  675.798307000122  679.870291152392
#
#          2002 [YR2002]     2003 [YR2003]     2004 [YR2004]     2005 [YR2005]  \
# 4      239.69945131126   248.15663454984  240.184903694364  257.175794656273
# ...

# %%
gdp_dataT['2000 [YR2000]']
# Out:
# 4                     ..
# 42      2085.58272052769
# 80      2530.01144247309
# 118                   ..
# 156      33700.762128571
#               ...
# 9048    1358.87355061492
# 9086    6672.63303446756
# 9124    766.138663048624
# 9162    582.624115719816
# 9200    675.798307000122
# Name: 2000 [YR2000], dtype: object
